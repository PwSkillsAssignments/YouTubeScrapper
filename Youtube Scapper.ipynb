# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import pandas as pd

# %% [markdown]
# #  Write a python program to extract the video URL of the first five videos.

# %%
import requests
import re
from datetime import datetime

# URL of the YouTube channel
channel_url = 'https://www.youtube.com/@PW-Foundation/videos'

# Send a GET request to the YouTube channel URL
response = requests.get(channel_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Use a regular expression to extract the content of ytInitialData
    match = re.search(r'var\s+ytInitialData\s*=\s*({.*?});', response.text, re.DOTALL)

    if match:
        # Extracted JSON string
        yt_initial_data_json = match.group(1)

        # Parse the JSON string
        import json
        yt_initial_data = json.loads(yt_initial_data_json)

# %%
yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][4]['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text']
# Out:
# 'COORDINATE GEOMETRY in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Maths'

# %%
channel_url = 'https://www.youtube.com/@PW-Foundation/videos'

# %%
# Send a GET request to the YouTube channel URL
response = requests.get(channel_url)
response
# Out:
# <Response [200]>

# %%
match = re.search(r'var\s+ytInitialData\s*=\s*({.*?});', response.text, re.DOTALL)
match
# Out:
# <re.Match object; span=(369902, 621702), match='var ytInitialData = {"responseContext":{"serviceT>

# %%
yt_initial_data_json = match.group(1)
# yt_initial_data_json

# %%
yt_initial_data = json.loads(yt_initial_data_json)
yt_initial_data
# Out:
# {'responseContext': {'serviceTrackingParams': [{'service': 'GFEEDBACK',
#     'params': [{'key': 'route', 'value': 'channel.videos'},
#      {'key': 'is_casual', 'value': 'false'},
#      {'key': 'is_owner', 'value': 'false'},
#      {'key': 'is_alc_surface', 'value': 'false'},
#      {'key': 'browse_id', 'value': 'UCphU2bAGmw304CFAzy0Enuw'},
#      {'key': 'browse_id_prefix', 'value': ''},
#      {'key': 'logged_in', 'value': '0'},
#      {'key': 'country-type', 'value': 'B'},
#      {'key': 'e',
#       'value': '9453588,9453589,23804281,23843878,23858057,23946420,23966208,23983296,23986022,23998056,24004644,24007246,24034168,24036948,24077241,24080738,24120819,24135310,24140247,24166867,24181174,24187377,24241378,24255543,24255545,24288664,24290971,24362616,24367579,24368940,24377598,24377910,24382552,24385728,24387949,24390675,24407446,24428788,24428941,24428945,24439361,24451319,24453989,24458317,24458324,24458329,24458839,24459436,24468724,24485421,24490203,24506515,24515423,24518452,24524098,24526644,24526770,24526787,24526794,24526799,24526806,24526811,24526823,24528550,24528557,24528573,24528584,24528640,24528649,24528661,24528664,24531225,24531244,24531254,24537200,24539025,24542367,24542452,24546060,24546075,24548627,24548629,24549786,24550458,24559327,24559699,24560416,24561210,24561383,24566687,24589493,24694842,24698452,24699899,39324569,39325334,39325347,39325405,39325421,39325428,39325486,39325496,39325500,39325518,39325522,39325529,51003636,51004018,51006181,51009781,51009900,51010235,51012165,51012291,51012659,51014091,51016856,51017346,51019626,51020570,51021953,51022793,51025415,51026715,51027426,51027870,51028271,51029412,51030103,51031654,51033399,51033577,51035289,51036511,51037346,51037351,51037540,51037819,51037893,51038399,51038805,51039200,51039493,51040388,51040836,51041333,51041497,51042824,51043948,51043998,51045885,51045889,51045969,51048240,51048279,51049006,51050360,51053689,51055048,51055993,51057501,51057534,51057746,51057811,51057820,51057846,51057857,51059543,51060353,51061000,51061018,51062131,51063125,51063140,51063147,51063160,51063643,51064006,51065651,51065706,51069269,51069593,51069839,51070203,51070732,51072529,51072748,51073514,51073619,51074183,51074391,51074662,51074717,51074739,51074990,51075837,51075989,51076209,51077149,51077834,51077911,51078193,51078372,51079307,51079353,51080182,51080511,51080713,51082017,51083014,51083234,51084279,51084290,51084695,51086362,51086857,51088825,51090888'}]},
#    {'service': 'GOOGLE_HELP',
#     'params': [{'key': 'browse_id', 'value': 'UCphU2bAGmw304CFAzy0Enuw'},
#      {'key': 'browse_id_prefix', 'value': ''}]},
#    {'service': 'CSI',
#     'params': [{'key': 'c', 'value': 'WEB'},
#      {'key': 'cver', 'value': '2.20231219.04.00'},
#      {'key': 'yt_li', 'value': '0'},
#      {'key': 'GetChannelPage_rid', 'value': '0xf11464c7ed23a6b0'}]},
#    {'service': 'GUIDED_HELP', 'params': [{'key': 'logged_in', 'value': '0'}]},
#    {'service': 'ECATCHER',
#     'params': [{'key': 'client.version', 'value': '2.20231219'},
#      {'key': 'client.name', 'value': 'WEB'},
#      {'key': 'client.fexp',
#       'value': '24181174,24542367,51003636,39325518,51074739,51037351,24428941,51041333,24566687,24288664,51025415,51083014,24526811,23946420,51045885,23804281,51080713,51074990,51074717,51057820,24589493,24368940,39325496,51004018,51075989,24531225,24135310,24080738,24007246,9453589,51028271,24531254,23966208,24290971,24528550,51080182,51019626,51065651,24559699,51012659,51055993,24550458,24528557,24140247,51057857,51039493,51009900,51026715,51073619,51012291,24526787,51057746,24546060,51035289,51033577,51070203,24526823,23843878,24468724,24515423,24506515,24524098,51063125,51038805,51086362,24428788,51036511,23983296,51061018,24539025,24546075,24526644,24453989,51057811,51077911,24120819,24387949,51042824,51072748,24458324,51017346,24439361,24548627,24390675,24698452,51037819,24528664,23986022,51077149,24377910,24458317,24528649,23858057,51039200,51078372,24694842,39325529,51063140,39325486,51065706,24385728,24528584,51063643,24034168,51063147,39325522,51016856,24526794,24537200,24485421,24531244,51033399,24559327,51045889,39325428,51029412,51082017,24518452,24407446,51009781,39325500,51057501,24542452,51050360,39325421,24451319,51079307,24548629,24490203,51086857,39325334,51021953,51084290,51030103,51062131,51078193,24699899,24526806,51048240,51040388,51053689,51027426,24549786,24362616,51037893,24526770,24255543,51063160,51076209,24528640,51069269,51077834,51055048,23998056,51037540,51043948,51074662,24561383,51083234,39325405,24458329,51069593,51045969,51059543,51037346,51057846,24561210,51043998,24458839,39325347,24528661,24428945,51012165,24187377,51064006,24367579,24526799,51088825,9453588,24560416,24166867,51038399,24255545,51010235,51061000,51041497,51073514,51072529,51031654,51074183,51070732,51084695,51060353,51057534,51075837,51079353,51084279,51074391,51014091,51022793,24382552,51069839,51048279,51027870,51040836,24036948,24241378,51080511,51090888,24377598,39324569,51020570,24004644,24459436,24077241,51006181,51049006,24528573'}]}],
#   'maxAgeSeconds': 300,
#   'mainAppWebResponseContext': {'loggedOut': True,
#    'trackingParam': 'kx_fmPxhoPZRe9AYYiKG7wO30SzD8-Ta0inFg-mggim3gAwRgkuswmIBwOcCE59TDtslLKPQ-SS'},
#   'webResponseContextExtensionData': {'ytConfigData': {'visitorData': 'CgtMUWFqa2FEUGFRcyiasMmsBjIKCgJJThIEGgAgWg%3D%3D',
#     'rootVisualElementType': 3611},
#    'hasDecorated': True}},
#  'contents': {'twoColumnBrowseResultsRenderer': {'tabs': [{'tabRenderer': {'endpoint': {'clickTrackingParams': 'CNsBEPCTARgFIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#        'commandMetadata': {'webCommandMetadata': {'url': '/@PW-Foundation/featured',
#          'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#          'rootVe': 3611,
#          'apiUrl': '/youtubei/v1/browse'}},
#        'browseEndpoint': {'browseId': 'UCphU2bAGmw304CFAzy0Enuw',
#         'params': 'EghmZWF0dXJlZPIGBAoCMgA%3D',
#         'canonicalBaseUrl': '/@PW-Foundation'}},
#       'title': 'Home',
#       'trackingParams': 'CNsBEPCTARgFIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#     {'tabRenderer': {'endpoint': {'clickTrackingParams': 'CB8Q8JMBGAYiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#        'commandMetadata': {'webCommandMetadata': {'url': '/@PW-Foundation/videos',
#          'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#          'rootVe': 3611,
#          'apiUrl': '/youtubei/v1/browse'}},
#        'browseEndpoint': {'browseId': 'UCphU2bAGmw304CFAzy0Enuw',
#         'params': 'EgZ2aWRlb3PyBgQKAjoA',
#         'canonicalBaseUrl': '/@PW-Foundation'}},
#       'title': 'Videos',
#       'selected': True,
#       'content': {'richGridRenderer': {'contents': [{'richItemRenderer': {'content': {'videoRenderer': {'videoId': 'J071v8HBuhw',
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCw_kN32ddCjQxOhPjLBzATWxcFzg',
#                 'width': 168,
#                 'height': 94},
#                {'url': 'https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBnz2u4p1-QC5SwIyUmO_2PPuNFeg',
#                 'width': 196,
#                 'height': 110},
#                {'url': 'https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBajYRPyG4DcVrb86r2EQAtl2p0IA',
#                 'width': 246,
#                 'height': 138},
#                {'url': 'https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBTKUaqBEX3nOMdnYhqVSqOt9OKrA',
#                 'width': 336,
#                 'height': 188}]},
#              'title': {'runs': [{'text': 'SCIENCE BOARD मैं कैसे आएँगे 100/100 🎯 | Important TIPS & TRICKS🚨 | Class-10th'}],
#               'accessibility': {'accessibilityData': {'label': 'SCIENCE BOARD मैं कैसे आएँगे 100/100 🎯 | Important TIPS & TRICKS🚨 | Class-10th by Physics Wallah Foundation 96,163 views 17 hours ago 30 minutes'}}},
#              'descriptionSnippet': {'runs': [{'text': '👉 Practice Sheet - Go to Batch - Subject Section - Open DPP PDF Section.\n📕 Warrior Series Class 10th: https://physicswallah.onelink.me/ZAZB/xg50bxxu\n📝 Telegram For Notes:- https://t.me/fou...'}]},
#              'publishedTimeText': {'simpleText': '17 hours ago'},
#              'lengthText': {'accessibility': {'accessibilityData': {'label': '30 minutes, 58 seconds'}},
#               'simpleText': '30:58'},
#              'viewCountText': {'simpleText': '96,163 views'},
#              'navigationEndpoint': {'clickTrackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKWhhVQ3BoVTJiQUdtdzMwNENGQXp5MEVudXeaAQMQ8jg=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=J071v8HBuhw',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'J071v8HBuhw',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr2---sn-25g5qpnxpo-2o9e.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=274ef5bfc1c1ba1c&ip=103.153.166.106&initcwndbps=1131250&mt=1704089093&oweuc='}}}}},
#              'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#                 'style': 'BADGE_STYLE_TYPE_VERIFIED',
#                 'tooltip': 'Verified',
#                 'trackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                 'accessibilityData': {'label': 'Verified'}}}],
#              'trackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKQJz0ho78t72nJw==',
#              'showActionMenu': False,
#              'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '96K views'}},
#               'simpleText': '96K views'},
#              'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#                   'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CNoBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                    'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                     'actions': [{'clickTrackingParams': 'CNoBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'addToPlaylistCommand': {'openMiniplayer': True,
#                        'videoId': 'J071v8HBuhw',
#                        'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                        'onCreateListCommand': {'clickTrackingParams': 'CNoBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                           'apiUrl': '/youtubei/v1/playlist/create'}},
#                         'createPlaylistServiceEndpoint': {'videoIds': ['J071v8HBuhw'],
#                          'params': 'CAQ%3D'}},
#                        'videoIds': ['J071v8HBuhw']}}]}},
#                   'trackingParams': 'CNoBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#                 {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#                   'icon': {'iconType': 'SHARE'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                      'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#                    'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtKMDcxdjhIQnVodw%3D%3D',
#                     'commands': [{'clickTrackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'openPopupAction': {'popup': {'unifiedSharePanelRenderer': {'trackingParams': 'CNkBEI5iIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                          'showLoadingSpinner': True}},
#                        'popupType': 'DIALOG',
#                        'beReused': True}}]}},
#                   'trackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}}],
#                'trackingParams': 'CNYBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#              'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '30 minutes, 58 seconds'}},
#                  'simpleText': '30:58'},
#                 'style': 'DEFAULT'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#                 'untoggledIcon': {'iconType': 'WATCH_LATER'},
#                 'toggledIcon': {'iconType': 'CHECK'},
#                 'untoggledTooltip': 'Watch Later',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CNgBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'addedVideoId': 'J071v8HBuhw',
#                     'action': 'ACTION_ADD_VIDEO'}]}},
#                 'toggledServiceEndpoint': {'clickTrackingParams': 'CNgBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                     'removedVideoId': 'J071v8HBuhw'}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Watch Later'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CNgBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                 'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#                 'untoggledTooltip': 'Add to queue',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CNcBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                  'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                   'actions': [{'clickTrackingParams': 'CNcBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                     'addToPlaylistCommand': {'openMiniplayer': True,
#                      'videoId': 'J071v8HBuhw',
#                      'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                      'onCreateListCommand': {'clickTrackingParams': 'CNcBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                         'apiUrl': '/youtubei/v1/playlist/create'}},
#                       'createPlaylistServiceEndpoint': {'videoIds': ['J071v8HBuhw'],
#                        'params': 'CAQ%3D'}},
#                      'videoIds': ['J071v8HBuhw']}}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CNcBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}]}},
#            'trackingParams': 'CNUBEJmNBRgAIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#          {'richItemRenderer': {'content': {'videoRenderer': {'videoId': 'TovkhURONCA',
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLDjb130vnocPBIe2_m-pacCIU4bIA',
#                 'width': 168,
#                 'height': 94},
#                {'url': 'https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBgfVddVjnPPhfyavu2AQByJYnhQA',
#                 'width': 196,
#                 'height': 110},
#                {'url': 'https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDRSDdrKVoctqqh4XVeQuKaiSfO1w',
#                 'width': 246,
#                 'height': 138},
#                {'url': 'https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDOTla0CTKNCnfzKpBdVMqDYgeKAg',
#                 'width': 336,
#                 'height': 188}]},
#              'title': {'runs': [{'text': 'FORCE AND LAWS OF MOTION in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Science'}],
#               'accessibility': {'accessibilityData': {'label': 'FORCE AND LAWS OF MOTION in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Science by Physics Wallah Foundation 10,116 views 1 day ago 2 hours, 5 minutes'}}},
#              'descriptionSnippet': {'runs': [{'text': '👉 Practice Sheet - Go to Batch - Subject Section - Open DPP PDF Section.\n📕 SPRINT Class-9th - https://physicswallah.onelink.me/ZAZB/0y4x6bma\n📕 Telegram For Quizzes:- https://t.me/foundatio...'}]},
#              'publishedTimeText': {'simpleText': '1 day ago'},
#              'lengthText': {'accessibility': {'accessibilityData': {'label': '2 hours, 5 minutes, 45 seconds'}},
#               'simpleText': '2:05:45'},
#              'viewCountText': {'simpleText': '10,116 views'},
#              'navigationEndpoint': {'clickTrackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKWhhVQ3BoVTJiQUdtdzMwNENGQXp5MEVudXeaAQMQ8jg=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=TovkhURONCA',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'TovkhURONCA',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-25g5qpnxpo-2o9l.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=4e8be485444e3420&ip=103.153.166.106&initcwndbps=900000&mt=1704089093&oweuc='}}}}},
#              'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#                 'style': 'BADGE_STYLE_TYPE_VERIFIED',
#                 'tooltip': 'Verified',
#                 'trackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                 'accessibilityData': {'label': 'Verified'}}}],
#              'trackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKQKDouKLUkPnFTg==',
#              'showActionMenu': False,
#              'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '10K views'}},
#               'simpleText': '10K views'},
#              'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#                   'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CNQBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                    'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                     'actions': [{'clickTrackingParams': 'CNQBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'addToPlaylistCommand': {'openMiniplayer': True,
#                        'videoId': 'TovkhURONCA',
#                        'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                        'onCreateListCommand': {'clickTrackingParams': 'CNQBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                           'apiUrl': '/youtubei/v1/playlist/create'}},
#                         'createPlaylistServiceEndpoint': {'videoIds': ['TovkhURONCA'],
#                          'params': 'CAQ%3D'}},
#                        'videoIds': ['TovkhURONCA']}}]}},
#                   'trackingParams': 'CNQBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#                 {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#                   'icon': {'iconType': 'SHARE'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                      'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#                    'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtUb3ZraFVST05DQQ%3D%3D',
#                     'commands': [{'clickTrackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'openPopupAction': {'popup': {'unifiedSharePanelRenderer': {'trackingParams': 'CNMBEI5iIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                          'showLoadingSpinner': True}},
#                        'popupType': 'DIALOG',
#                        'beReused': True}}]}},
#                   'trackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}}],
#                'trackingParams': 'CNABENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#              'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '2 hours, 5 minutes, 45 seconds'}},
#                  'simpleText': '2:05:45'},
#                 'style': 'DEFAULT'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#                 'untoggledIcon': {'iconType': 'WATCH_LATER'},
#                 'toggledIcon': {'iconType': 'CHECK'},
#                 'untoggledTooltip': 'Watch Later',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CNIBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'addedVideoId': 'TovkhURONCA',
#                     'action': 'ACTION_ADD_VIDEO'}]}},
#                 'toggledServiceEndpoint': {'clickTrackingParams': 'CNIBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                     'removedVideoId': 'TovkhURONCA'}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Watch Later'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CNIBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                 'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#                 'untoggledTooltip': 'Add to queue',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CNEBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                  'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                   'actions': [{'clickTrackingParams': 'CNEBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                     'addToPlaylistCommand': {'openMiniplayer': True,
#                      'videoId': 'TovkhURONCA',
#                      'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                      'onCreateListCommand': {'clickTrackingParams': 'CNEBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                         'apiUrl': '/youtubei/v1/playlist/create'}},
#                       'createPlaylistServiceEndpoint': {'videoIds': ['TovkhURONCA'],
#                        'params': 'CAQ%3D'}},
#                      'videoIds': ['TovkhURONCA']}}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CNEBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}]}},
#            'trackingParams': 'CM8BEJmNBRgBIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#          {'richItemRenderer': {'content': {'videoRenderer': {'videoId': 's6DFsuvWl-4',
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLC9KPpKSC9WIE9Yu8R-zEWHo3Oq5Q',
#                 'width': 168,
#                 'height': 94},
#                {'url': 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBxXyaFiuGCMXEnXw_Udl7b9Io-AA',
#                 'width': 196,
#                 'height': 110},
#                {'url': 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLD7KRDVpcugQCh49TM2mYXGz8oUaA',
#                 'width': 246,
#                 'height': 138},
#                {'url': 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA8L0iQviPSsLoGgwunhQFgCXvzPA',
#                 'width': 336,
#                 'height': 188}]},
#              'title': {'runs': [{'text': 'LINEAR EQUATIONS IN TWO VARIABLES  in 1 Shot || FULL Chapter (Concepts+PYQs) || Class 9th Maths'}],
#               'accessibility': {'accessibilityData': {'label': 'LINEAR EQUATIONS IN TWO VARIABLES  in 1 Shot || FULL Chapter (Concepts+PYQs) || Class 9th Maths by Physics Wallah Foundation 7,524 views 1 day ago 2 hours, 2 minutes'}}},
#              'descriptionSnippet': {'runs': [{'text': '👉 Practice Sheet - Go to Batch - Subject Section - Open DPP PDF Section.\n📕 SPRINT Class-9th - https://physicswallah.onelink.me/ZAZB/0y4x6bma\n📕 Telegram For Quizzes:- https://t.me/foundatio...'}]},
#              'publishedTimeText': {'simpleText': '1 day ago'},
#              'lengthText': {'accessibility': {'accessibilityData': {'label': '2 hours, 2 minutes, 26 seconds'}},
#               'simpleText': '2:02:26'},
#              'viewCountText': {'simpleText': '7,524 views'},
#              'navigationEndpoint': {'clickTrackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKWhhVQ3BoVTJiQUdtdzMwNENGQXp5MEVudXeaAQMQ8jg=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=s6DFsuvWl-4',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 's6DFsuvWl-4',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr2---sn-25g5qpnxpo-2o9e.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=b3a0c5b2ebd697ee&ip=103.153.166.106&initcwndbps=1131250&mt=1704089093&oweuc='}}}}},
#              'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#                 'style': 'BADGE_STYLE_TYPE_VERIFIED',
#                 'tooltip': 'Verified',
#                 'trackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                 'accessibilityData': {'label': 'Verified'}}}],
#              'trackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKQO6v2t6utrHQswE=',
#              'showActionMenu': False,
#              'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '7.5K views'}},
#               'simpleText': '7.5K views'},
#              'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#                   'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CM4BEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                    'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                     'actions': [{'clickTrackingParams': 'CM4BEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'addToPlaylistCommand': {'openMiniplayer': True,
#                        'videoId': 's6DFsuvWl-4',
#                        'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                        'onCreateListCommand': {'clickTrackingParams': 'CM4BEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                           'apiUrl': '/youtubei/v1/playlist/create'}},
#                         'createPlaylistServiceEndpoint': {'videoIds': ['s6DFsuvWl-4'],
#                          'params': 'CAQ%3D'}},
#                        'videoIds': ['s6DFsuvWl-4']}}]}},
#                   'trackingParams': 'CM4BEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#                 {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#                   'icon': {'iconType': 'SHARE'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                      'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#                    'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtzNkRGc3V2V2wtNA%3D%3D',
#                     'commands': [{'clickTrackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'openPopupAction': {'popup': {'unifiedSharePanelRenderer': {'trackingParams': 'CM0BEI5iIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                          'showLoadingSpinner': True}},
#                        'popupType': 'DIALOG',
#                        'beReused': True}}]}},
#                   'trackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}}],
#                'trackingParams': 'CMoBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#              'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '2 hours, 2 minutes, 26 seconds'}},
#                  'simpleText': '2:02:26'},
#                 'style': 'DEFAULT'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#                 'untoggledIcon': {'iconType': 'WATCH_LATER'},
#                 'toggledIcon': {'iconType': 'CHECK'},
#                 'untoggledTooltip': 'Watch Later',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CMwBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'addedVideoId': 's6DFsuvWl-4',
#                     'action': 'ACTION_ADD_VIDEO'}]}},
#                 'toggledServiceEndpoint': {'clickTrackingParams': 'CMwBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                     'removedVideoId': 's6DFsuvWl-4'}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Watch Later'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CMwBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                 'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#                 'untoggledTooltip': 'Add to queue',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CMsBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                  'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                   'actions': [{'clickTrackingParams': 'CMsBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                     'addToPlaylistCommand': {'openMiniplayer': True,
#                      'videoId': 's6DFsuvWl-4',
#                      'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                      'onCreateListCommand': {'clickTrackingParams': 'CMsBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                         'apiUrl': '/youtubei/v1/playlist/create'}},
#                       'createPlaylistServiceEndpoint': {'videoIds': ['s6DFsuvWl-4'],
#                        'params': 'CAQ%3D'}},
#                      'videoIds': ['s6DFsuvWl-4']}}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CMsBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}]}},
#            'trackingParams': 'CMkBEJmNBRgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#          {'richItemRenderer': {'content': {'videoRenderer': {'videoId': 'SZb-hh03X8c',
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBsEKN2lHM7iHBsjmtenFx9MTQ_7w',
#                 'width': 168,
#                 'height': 94},
#                {'url': 'https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCiurk7oOOAk93XdsHxfM9Kn3DT8g',
#                 'width': 196,
#                 'height': 110},
#                {'url': 'https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLB7XeV9RO19m_GUoJcBwLRokgC9Iw',
#                 'width': 246,
#                 'height': 138},
#                {'url': 'https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDAjsWZdppCe0OSuPcX9B2GZOwm5A',
#                 'width': 336,
#                 'height': 188}]},
#              'title': {'runs': [{'text': 'POVERTY AS A CHALLENGE in 1 Shot || FULL Chapter Coverage (THEORY+PYQs) || Class 9th SST'}],
#               'accessibility': {'accessibilityData': {'label': 'POVERTY AS A CHALLENGE in 1 Shot || FULL Chapter Coverage (THEORY+PYQs) || Class 9th SST by Physics Wallah Foundation 7,373 views 2 days ago 42 minutes'}}},
#              'descriptionSnippet': {'runs': [{'text': '👉 Practice Sheet - Go to Batch - Subject Section - Open DPP PDF Section.\n📕 SPRINT Class-9th - https://physicswallah.onelink.me/ZAZB/0y4x6bma\n📕 Telegram For Quizzes:- https://t.me/foundatio...'}]},
#              'publishedTimeText': {'simpleText': '2 days ago'},
#              'lengthText': {'accessibility': {'accessibilityData': {'label': '42 minutes, 6 seconds'}},
#               'simpleText': '42:06'},
#              'viewCountText': {'simpleText': '7,373 views'},
#              'navigationEndpoint': {'clickTrackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKWhhVQ3BoVTJiQUdtdzMwNENGQXp5MEVudXeaAQMQ8jg=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=SZb-hh03X8c',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'SZb-hh03X8c',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-25g5qpnxpo-2o9l.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=4996fe861d375fc7&ip=103.153.166.106&initcwndbps=900000&mt=1704089093&oweuc='}}}}},
#              'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#                 'style': 'BADGE_STYLE_TYPE_VERIFIED',
#                 'tooltip': 'Verified',
#                 'trackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                 'accessibilityData': {'label': 'Verified'}}}],
#              'trackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKQMe_3enh0L_LSQ==',
#              'showActionMenu': False,
#              'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '7.3K views'}},
#               'simpleText': '7.3K views'},
#              'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#                   'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CMgBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                    'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                     'actions': [{'clickTrackingParams': 'CMgBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'addToPlaylistCommand': {'openMiniplayer': True,
#                        'videoId': 'SZb-hh03X8c',
#                        'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                        'onCreateListCommand': {'clickTrackingParams': 'CMgBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                           'apiUrl': '/youtubei/v1/playlist/create'}},
#                         'createPlaylistServiceEndpoint': {'videoIds': ['SZb-hh03X8c'],
#                          'params': 'CAQ%3D'}},
#                        'videoIds': ['SZb-hh03X8c']}}]}},
#                   'trackingParams': 'CMgBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#                 {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#                   'icon': {'iconType': 'SHARE'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                      'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#                    'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtTWmItaGgwM1g4Yw%3D%3D',
#                     'commands': [{'clickTrackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'openPopupAction': {'popup': {'unifiedSharePanelRenderer': {'trackingParams': 'CMcBEI5iIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                          'showLoadingSpinner': True}},
#                        'popupType': 'DIALOG',
#                        'beReused': True}}]}},
#                   'trackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}}],
#                'trackingParams': 'CMQBENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#              'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '42 minutes, 6 seconds'}},
#                  'simpleText': '42:06'},
#                 'style': 'DEFAULT'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#                 'untoggledIcon': {'iconType': 'WATCH_LATER'},
#                 'toggledIcon': {'iconType': 'CHECK'},
#                 'untoggledTooltip': 'Watch Later',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CMYBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'addedVideoId': 'SZb-hh03X8c',
#                     'action': 'ACTION_ADD_VIDEO'}]}},
#                 'toggledServiceEndpoint': {'clickTrackingParams': 'CMYBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#                  'playlistEditEndpoint': {'playlistId': 'WL',
#                   'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#                     'removedVideoId': 'SZb-hh03X8c'}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Watch Later'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CMYBEPnnAxgCIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                 'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#                 'untoggledTooltip': 'Add to queue',
#                 'toggledTooltip': 'Added',
#                 'untoggledServiceEndpoint': {'clickTrackingParams': 'CMUBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                  'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                   'actions': [{'clickTrackingParams': 'CMUBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                     'addToPlaylistCommand': {'openMiniplayer': True,
#                      'videoId': 'SZb-hh03X8c',
#                      'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                      'onCreateListCommand': {'clickTrackingParams': 'CMUBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                         'apiUrl': '/youtubei/v1/playlist/create'}},
#                       'createPlaylistServiceEndpoint': {'videoIds': ['SZb-hh03X8c'],
#                        'params': 'CAQ%3D'}},
#                      'videoIds': ['SZb-hh03X8c']}}]}},
#                 'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#                 'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#                 'trackingParams': 'CMUBEMfsBBgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#               {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}]}},
#            'trackingParams': 'CMMBEJmNBRgDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#          {'richItemRenderer': {'content': {'videoRenderer': {'videoId': 'CDJlqkp1hfI',
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLBVnRj3vfC4Z8oe8TfM_sw1b36b6w',
#                 'width': 168,
#                 'height': 94},
#                {'url': 'https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCUNiowMvxLn7Qb9kDvnEo4d8RJWA',
#                 'width': 196,
#                 'height': 110},
#                {'url': 'https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCSmLfNRUklURSWBjkrfvDM69gTQg',
#                 'width': 246,
#                 'height': 138},
#                {'url': 'https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLByDvDCQp_1g8MagrvYkJazG3FJgA',
#                 'width': 336,
#                 'height': 188}]},
#              'title': {'runs': [{'text': 'COORDINATE GEOMETRY in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Maths'}],
#               'accessibility': {'accessibilityData': {'label': 'COORDINATE GEOMETRY in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Maths by Physics Wallah Foundation 8,775 views 3 days ago 1 hour, 36 minutes'}}},
#              'descriptionSnippet': {'runs': [{'text': '👉 Practice Sheet - Go to Batch - Subject Section - Open DPP PDF Section.\n📕 SPRINT Class-9th - https://physicswallah.onelink.me/ZAZB/0y4x6bma\n📕 Telegram For Quizzes:- https://t.me/foundatio...'}]},
#              'publishedTimeText': {'simpleText': '3 days ago'},
#              'lengthText': {'accessibility': {'accessibilityData': {'label': '1 hour, 36 minutes, 51 seconds'}},
#               'simpleText': '1:36:51'},
#              'viewCountText': {'simpleText': '8,775 views'},
#              'navigationEndpoint': {'clickTrackingParams': 'CL4BENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKWhhVQ3BoVTJiQUdtdzMwNENGQXp5MEVudXeaAQMQ8jg=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=CDJlqkp1hfI',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'CDJlqkp1hfI',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-25g5qpnxpo-2o9l.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=083265aa4a7585f2&ip=103.153.166.106&initcwndbps=900000&mt=1704089093&oweuc='}}}}},
#              'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#                 'style': 'BADGE_STYLE_TYPE_VERIFIED',
#                 'tooltip': 'Verified',
#                 'trackingParams': 'CL4BENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                 'accessibilityData': {'label': 'Verified'}}}],
#              'trackingParams': 'CL4BENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABKQPKL1tOktZmZCA==',
#              'showActionMenu': False,
#              'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '8.7K views'}},
#               'simpleText': '8.7K views'},
#              'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#                   'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CMIBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#                    'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#                     'actions': [{'clickTrackingParams': 'CMIBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                       'addToPlaylistCommand': {'openMiniplayer': True,
#                        'videoId': 'CDJlqkp1hfI',
#                        'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                        'onCreateListCommand': {'clickTrackingParams': 'CMIBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                           'apiUrl': '/youtubei/v1/playlist/create'}},
#                         'createPlaylistServiceEndpoint': {'videoIds': ['CDJlqkp1hfI'],
#                          'params': 'CAQ%3D'}},
#                        'videoIds': ['CDJlqkp1hfI']}}]}},
#                   'trackingParams': 'CMIBEP6YBBgGIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#                 {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#                   'icon': {'iconType': 'SHARE'},
#                   'serviceEndpoint': {'clickTrackingParams': 'CL4BENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#                    'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                      'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#                    'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtDREpscWtwMWhmSQ%3D%3D',
#                     'commands': [{'clickTrackingParams': 'CL4BENwwIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
# ...
#    'countryCode': 'IN',
#    'topbarButtons': [{'topbarMenuButtonRenderer': {'icon': {'iconType': 'MORE_VERT'},
#       'menuRequest': {'clickTrackingParams': 'CAsQ_qsBGAAiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#        'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#          'apiUrl': '/youtubei/v1/account/account_menu'}},
#        'signalServiceEndpoint': {'signal': 'GET_ACCOUNT_MENU',
#         'actions': [{'clickTrackingParams': 'CAsQ_qsBGAAiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#           'openPopupAction': {'popup': {'multiPageMenuRenderer': {'trackingParams': 'CAwQ_6sBIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#              'style': 'MULTI_PAGE_MENU_STYLE_TYPE_SYSTEM',
#              'showLoadingSpinner': True}},
#            'popupType': 'DROPDOWN',
#            'beReused': True}}]}},
#       'trackingParams': 'CAsQ_qsBGAAiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#       'accessibility': {'accessibilityData': {'label': 'Settings'}},
#       'tooltip': 'Settings',
#       'style': 'STYLE_DEFAULT'}},
#     {'buttonRenderer': {'style': 'STYLE_SUGGESTIVE',
#       'size': 'SIZE_SMALL',
#       'text': {'runs': [{'text': 'Sign in'}]},
#       'icon': {'iconType': 'AVATAR_LOGGED_OUT'},
#       'navigationEndpoint': {'clickTrackingParams': 'CAoQ1IAEGAEiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#        'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den-GB%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252F%2540PW-Foundation%252Fvideos&hl=en-GB&ec=65620',
#          'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#          'rootVe': 83769}},
#        'signInEndpoint': {'idamTag': '65620'}},
#       'trackingParams': 'CAoQ1IAEGAEiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#       'targetId': 'topbar-signin'}}],
#    'hotkeyDialog': {'hotkeyDialogRenderer': {'title': {'runs': [{'text': 'Keyboard shortcuts'}]},
#      'sections': [{'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Playback'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle play/pause'}]},
#            'hotkey': 'k'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rewind 10 seconds'}]},
#            'hotkey': 'j'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Fast forward 10 seconds'}]},
#            'hotkey': 'l'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Previous video'}]},
#            'hotkey': 'P (SHIFT + p)'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Next video'}]},
#            'hotkey': 'N (SHIFT + n)'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Previous frame (while paused)'}]},
#            'hotkey': ',',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Comma'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Next frame (while paused)'}]},
#            'hotkey': '.',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Full stop'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Decrease playback rate'}]},
#            'hotkey': '< (SHIFT+,)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Less than or SHIFT + comma'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Increase playback rate'}]},
#            'hotkey': '> (SHIFT+.)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Greater than or SHIFT + full stop'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to specific point in the video (7 advances to 70% of duration)'}]},
#            'hotkey': '0..9'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to previous chapter'}]},
#            'hotkey': 'CONTROL + ←'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to next chapter'}]},
#            'hotkey': 'CONTROL + →'}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'General'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle full screen'}]},
#            'hotkey': 'f'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle theatre mode'}]},
#            'hotkey': 't'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle miniplayer'}]},
#            'hotkey': 'i'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Close miniplayer or current dialogue'}]},
#            'hotkey': 'ESCAPE'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle mute'}]},
#            'hotkey': 'm'}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Subtitles and closed captions'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'If the video supports captions, toggle captions ON/OFF'}]},
#            'hotkey': 'c'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through different text opacity levels'}]},
#            'hotkey': 'o'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through different window opacity levels'}]},
#            'hotkey': 'w'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through font sizes (increasing)'}]},
#            'hotkey': '+'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through font sizes (decreasing)'}]},
#            'hotkey': '-',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus'}}}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Spherical videos'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan up'}]},
#            'hotkey': 'w'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan left'}]},
#            'hotkey': 'a'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan down'}]},
#            'hotkey': 's'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan right'}]},
#            'hotkey': 'd'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Zoom in'}]},
#            'hotkey': '+ on numpad or ]',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Plus on number pad or right bracket'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Zoom out'}]},
#            'hotkey': '- on numpad or [',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus on number pad or left bracket'}}}}]}}],
#      'dismissButton': {'buttonRenderer': {'style': 'STYLE_BLUE_TEXT',
#        'size': 'SIZE_DEFAULT',
#        'isDisabled': False,
#        'text': {'runs': [{'text': 'Dismiss'}]},
#        'trackingParams': 'CAkQ8FsiEwifp9LGxLuDAxUixXMBHf7UAEo='}},
#      'trackingParams': 'CAgQteYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK'}},
#    'backButton': {'buttonRenderer': {'trackingParams': 'CAcQvIYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#      'command': {'clickTrackingParams': 'CAcQvIYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CAcQvIYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#          'signalAction': {'signal': 'HISTORY_BACK'}}]}}}},
#    'forwardButton': {'buttonRenderer': {'trackingParams': 'CAYQvYYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#      'command': {'clickTrackingParams': 'CAYQvYYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CAYQvYYDIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#          'signalAction': {'signal': 'HISTORY_FORWARD'}}]}}}},
#    'a11ySkipNavigationButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#      'size': 'SIZE_DEFAULT',
#      'isDisabled': False,
#      'text': {'runs': [{'text': 'Skip navigation'}]},
#      'trackingParams': 'CAUQ8FsiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#      'command': {'clickTrackingParams': 'CAUQ8FsiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CAUQ8FsiEwifp9LGxLuDAxUixXMBHf7UAEo=',
#          'signalAction': {'signal': 'SKIP_NAVIGATION'}}]}}}},
#    'voiceSearchButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#      'size': 'SIZE_DEFAULT',
#      'isDisabled': False,
#      'serviceEndpoint': {'clickTrackingParams': 'CAIQ7a8FIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CAIQ7a8FIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#          'openPopupAction': {'popup': {'voiceSearchDialogRenderer': {'placeholderHeader': {'runs': [{'text': 'Listening…'}]},
#             'promptHeader': {'runs': [{'text': "Didn't hear that. Try again."}]},
#             'exampleQuery1': {'runs': [{'text': "'Play Dua Lipa'"}]},
#             'exampleQuery2': {'runs': [{'text': "'Show me my subscriptions'"}]},
#             'promptMicrophoneLabel': {'runs': [{'text': 'Tap the microphone to try again'}]},
#             'loadingHeader': {'runs': [{'text': 'Working…'}]},
#             'connectionErrorHeader': {'runs': [{'text': 'No connection'}]},
#             'connectionErrorMicrophoneLabel': {'runs': [{'text': 'Check your connection and try again'}]},
#             'permissionsHeader': {'runs': [{'text': 'Waiting for permission'}]},
#             'permissionsSubtext': {'runs': [{'text': 'Allow microphone access to search with voice'}]},
#             'disabledHeader': {'runs': [{'text': 'Search with your voice'}]},
#             'disabledSubtext': {'runs': [{'text': 'To search by voice, go to your browser settings and allow access to microphone'}]},
#             'microphoneButtonAriaLabel': {'runs': [{'text': 'Cancel'}]},
#             'exitButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#               'size': 'SIZE_DEFAULT',
#               'isDisabled': False,
#               'icon': {'iconType': 'CLOSE'},
#               'trackingParams': 'CAQQ0LEFIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#               'accessibilityData': {'accessibilityData': {'label': 'Cancel'}}}},
#             'trackingParams': 'CAMQ7q8FIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#             'microphoneOffPromptHeader': {'runs': [{'text': 'Microphone off. Try again.'}]}}},
#           'popupType': 'TOP_ALIGNED_DIALOG'}}]}},
#      'icon': {'iconType': 'MICROPHONE_ON'},
#      'tooltip': 'Search with your voice',
#      'trackingParams': 'CAIQ7a8FIhMIn6fSxsS7gwMVIsVzAR3-1ABK',
#      'accessibilityData': {'accessibilityData': {'label': 'Search with your voice'}}}}}},
#  'microformat': {'microformatDataRenderer': {'urlCanonical': 'https://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw',
#    'title': 'Physics Wallah Foundation',
#    'description': 'Physics Wallah Foundation provides the best quality educational content for 10th and 9th grade students, targeting board or school exams in 2024 We provide w...',
#    'thumbnail': {'thumbnails': [{'url': 'https://yt3.googleusercontent.com/ZhXrPzcpLJxFRu21_fawmLWkwUoAWb3DSe04Ey-9sTXwBDnj22bH5217PQOCsRp7dWJf41aa=s200-c-k-c0x00ffffff-no-rj?days_since_epoch=19723',
#       'width': 200,
#       'height': 200}]},
#    'siteName': 'YouTube',
#    'appName': 'YouTube',
#    'androidPackage': 'com.google.android.youtube',
#    'iosAppStoreId': '544007664',
#    'iosAppArguments': 'https://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw',
#    'ogType': 'yt-fb-app:channel',
#    'urlApplinksWeb': 'https://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw?feature=applinks',
#    'urlApplinksIos': 'vnd.youtube://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw?feature=applinks',
#    'urlApplinksAndroid': 'vnd.youtube://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw?feature=applinks',
#    'urlTwitterIos': 'vnd.youtube://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw?feature=twitter-deep-link',
#    'urlTwitterAndroid': 'vnd.youtube://www.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw?feature=twitter-deep-link',
#    'twitterCardType': 'summary',
#    'twitterSiteHandle': '@YouTube',
#    'schemaDotOrgType': 'http://schema.org/http://schema.org/YoutubeChannelV2',
#    'noindex': False,
#    'unlisted': False,
#    'familySafe': True,
#    'tags': ['class 9',
#     'class 10',
#     'cbse class 9',
#     'cbse class 10',
#     'class 10 board exam',
#     'board exam class 10',
#     'board exam',
#     'class 9 science',
#     'class 9 sst',
#     'class 9 maths',
#     'class 10 maths',
#     'maths',
#     'maths class 10',
#     'science',
#     'science class 10',
#     'sst class 10',
#     'cbse board',
#     'icse board',
#     'board exam preparation',
#     'pw foundation',
#     'physics wallah foundation',
#     'udaan'],
#    'availableCountries': ['TL',
#     'LY',
#     'YT',
#     'HT',
#     'ME',
#     'AS',
#     'BS',
#     'GR',
#     'SG',
#     'NA',
#     'CR',
#     'MR',
#     'TZ',
#     'LV',
#     'MQ',
#     'IM',
#     'BL',
#     'VG',
#     'NR',
#     'IS',
#     'AI',
#     'DM',
#     'LR',
#     'RW',
#     'AE',
#     'GQ',
#     'VE',
#     'HU',
#     'LB',
#     'CN',
#     'ET',
#     'PR',
#     'WF',
#     'TV',
#     'PY',
#     'GF',
#     'PH',
#     'ML',
#     'MO',
#     'AL',
#     'KE',
#     'AG',
#     'GI',
#     'IN',
#     'MX',
#     'IT',
#     'ID',
#     'SE',
#     'SY',
#     'BR',
#     'TO',
#     'TM',
#     'FO',
#     'SR',
#     'GB',
#     'SV',
#     'BQ',
#     'NC',
#     'CA',
#     'MK',
#     'GN',
#     'RU',
#     'IE',
#     'TW',
#     'GM',
#     'LA',
#     'MV',
#     'BO',
#     'SL',
#     'ER',
#     'QA',
#     'FI',
#     'KN',
#     'PN',
#     'EH',
#     'KR',
#     'CO',
#     'MN',
#     'MA',
#     'GS',
#     'IR',
#     'MH',
#     'AX',
#     'VU',
#     'TJ',
#     'CL',
#     'TD',
#     'MT',
#     'HN',
#     'CD',
#     'LI',
#     'BE',
#     'MC',
#     'NE',
#     'TC',
#     'TT',
#     'UA',
#     'BM',
#     'WS',
#     'TN',
#     'AM',
#     'BG',
#     'PM',
#     'KZ',
#     'TG',
#     'IL',
#     'KM',
#     'TH',
#     'GP',
#     'SD',
#     'SN',
#     'NU',
#     'PE',
#     'MP',
#     'AD',
#     'TK',
#     'BV',
#     'NG',
#     'UM',
#     'CZ',
#     'SI',
#     'SB',
#     'CV',
#     'MD',
#     'AT',
#     'FK',
#     'CY',
#     'LU',
#     'VN',
#     'NO',
#     'US',
#     'PK',
#     'ZW',
#     'CG',
#     'KI',
#     'TF',
#     'CK',
#     'BH',
#     'BN',
#     'AO',
#     'BT',
#     'IO',
#     'PG',
#     'ZM',
#     'BZ',
#     'NI',
#     'AQ',
#     'EC',
#     'MW',
#     'RE',
#     'DJ',
#     'EG',
#     'SK',
#     'BF',
#     'CF',
#     'ZA',
#     'CX',
#     'OM',
#     'JE',
#     'GG',
#     'KG',
#     'DE',
#     'GU',
#     'LC',
#     'RO',
#     'NP',
#     'IQ',
#     'NL',
#     'LK',
#     'DO',
#     'GT',
#     'DK',
#     'SA',
#     'BW',
#     'PF',
#     'HR',
#     'PL',
#     'RS',
#     'GA',
#     'CM',
#     'GY',
#     'VC',
#     'MU',
#     'NF',
#     'BA',
#     'SC',
#     'SH',
#     'PS',
#     'AW',
#     'VA',
#     'FJ',
#     'VI',
#     'GW',
#     'PT',
#     'CH',
#     'CC',
#     'MZ',
#     'SZ',
#     'AZ',
#     'FR',
#     'HM',
#     'MM',
#     'MS',
#     'PA',
#     'FM',
#     'JP',
#     'UY',
#     'SS',
#     'BB',
#     'UG',
#     'MY',
#     'GD',
#     'MF',
#     'SO',
#     'CI',
#     'BY',
#     'GE',
#     'JO',
#     'ST',
#     'JM',
#     'YE',
#     'CW',
#     'BJ',
#     'AR',
#     'DZ',
#     'KP',
#     'SM',
#     'KH',
#     'SX',
#     'GL',
#     'LT',
#     'NZ',
#     'MG',
#     'AF',
#     'AU',
#     'TR',
#     'PW',
#     'SJ',
#     'UZ',
#     'HK',
#     'BI',
#     'CU',
#     'GH',
#     'EE',
#     'ES',
#     'KW',
#     'KY',
#     'BD',
#     'LS'],
#    'linkAlternates': [{'hrefUrl': 'https://m.youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw'},
#     {'hrefUrl': 'android-app://com.google.android.youtube/http/youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw'},
#     {'hrefUrl': 'ios-app://544007664/http/youtube.com/channel/UCphU2bAGmw304CFAzy0Enuw'}]}}}

# %%
for i in range(5):
    print(yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text'])
# Out:
# THE LOST CHILD + ADVENTURE OF TOTO in 1 Shot || FULL Chapter (THEORY+PYQs) || Class-9th English
# SOCIALISM IN EUROPE & RUSSIAN REVOLUTION in 1 Shot || FULL Chapter (THEORY+PYQs) || Class 9th SST
# THE FUNDAMENTAL UNIT OF LIFE in 1 Shot | FULL Chapter Coverage (THEORY+PYQs) | Class-9th Biology
# TENSES + MODALS in 1 Shot | FULL Chapter Coverage (THEORY+PYQs) | Class-9th English
# WHAT IS DEMOCRACY? WHY DEMOCRACY? in 1 Shot | FULL Chapter Coverage (THEORY+PYQs) | Class-9th SST

# %%
yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][0]['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text']
# Out:
# 'SCIENCE BOARD मैं कैसे आएँगे 100/100 🎯 | Important TIPS & TRICKS🚨 | Class-10th'

# %%
'https://www.youtube.com' + yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][1]['richItemRenderer']['content']['videoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
# Out:
# 'https://www.youtube.com/watch?v=TovkhURONCA'

# %%
for i in range(5):
    print('https://www.youtube.com' + yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url'])
# Out:
# https://www.youtube.com/watch?v=J071v8HBuhw
# https://www.youtube.com/watch?v=TovkhURONCA
# https://www.youtube.com/watch?v=s6DFsuvWl-4
# https://www.youtube.com/watch?v=SZb-hh03X8c
# https://www.youtube.com/watch?v=CDJlqkp1hfI

# %%
# Out:
# 4

# %%
for i in range(5):
    print(yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['thumbnail']['thumbnails'][3]['url'])
# Out:
# https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBTKUaqBEX3nOMdnYhqVSqOt9OKrA
# https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDOTla0CTKNCnfzKpBdVMqDYgeKAg
# https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA8L0iQviPSsLoGgwunhQFgCXvzPA
# https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDAjsWZdppCe0OSuPcX9B2GZOwm5A
# https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLByDvDCQp_1g8MagrvYkJazG3FJgA

# %%
yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][2]['richItemRenderer']['content']['videoRenderer']['thumbnail']['thumbnails'][3]['url']
# Out:
# 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA8L0iQviPSsLoGgwunhQFgCXvzPA'

# %%
for i in range(5):
    print(yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['publishedTimeText']['simpleText'])
# Out:
# 17 hours ago
# 1 day ago
# 1 day ago
# 2 days ago
# 3 days ago

# %%
for i in range(5):
    print(yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['viewCountText']['simpleText'])
# Out:
# 96,163 views
# 10,116 views
# 7,524 views
# 7,373 views
# 8,775 views

# %%
for i in range(5):
    mydict = {
        'VideoName': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text'],
        'VideoLink': 'https://www.youtube.com' + yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url'],
        'VideoThumnail': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['thumbnail']['thumbnails'][3]['url'],
        'VideoTimeOfPost': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['publishedTimeText']['simpleText'],
        'VideoViews': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['viewCountText']['simpleText']
    }
    print(mydict)
# Out:
# {'VideoName': 'SCIENCE BOARD मैं कैसे आएँगे 100/100 🎯 | Important TIPS & TRICKS🚨 | Class-10th', 'VideoLink': 'https://www.youtube.com/watch?v=J071v8HBuhw', 'VideoThumnail': 'https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBTKUaqBEX3nOMdnYhqVSqOt9OKrA', 'VideoTimeOfPost': '17 hours ago', 'VideoViews': '96,163 views'}
# {'VideoName': 'FORCE AND LAWS OF MOTION in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Science', 'VideoLink': 'https://www.youtube.com/watch?v=TovkhURONCA', 'VideoThumnail': 'https://i.ytimg.com/vi/TovkhURONCA/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDOTla0CTKNCnfzKpBdVMqDYgeKAg', 'VideoTimeOfPost': '1 day ago', 'VideoViews': '10,116 views'}
# {'VideoName': 'LINEAR EQUATIONS IN TWO VARIABLES  in 1 Shot || FULL Chapter (Concepts+PYQs) || Class 9th Maths', 'VideoLink': 'https://www.youtube.com/watch?v=s6DFsuvWl-4', 'VideoThumnail': 'https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA8L0iQviPSsLoGgwunhQFgCXvzPA', 'VideoTimeOfPost': '1 day ago', 'VideoViews': '7,524 views'}
# {'VideoName': 'POVERTY AS A CHALLENGE in 1 Shot || FULL Chapter Coverage (THEORY+PYQs) || Class 9th SST', 'VideoLink': 'https://www.youtube.com/watch?v=SZb-hh03X8c', 'VideoThumnail': 'https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDAjsWZdppCe0OSuPcX9B2GZOwm5A', 'VideoTimeOfPost': '2 days ago', 'VideoViews': '7,373 views'}
# {'VideoName': 'COORDINATE GEOMETRY in 1 Shot || FULL Chapter Coverage (Concepts+PYQs) || Class 9th Maths', 'VideoLink': 'https://www.youtube.com/watch?v=CDJlqkp1hfI', 'VideoThumnail': 'https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLByDvDCQp_1g8MagrvYkJazG3FJgA', 'VideoTimeOfPost': '3 days ago', 'VideoViews': '8,775 views'}

# %%
def youtube_scrapping(channel_url, num_records):
    url = channel_url
    # Send a GET request to the YouTube channel URL
    response = requests.get(channel_url)
    if response.status_code == 200:
        match = re.search(r'var\s+ytInitialData\s*=\s*({.*?});', response.text, re.DOTALL)
        yt_data_json = match.group(1)
        yt_initial_data = json.loads(yt_initial_data_json)
        channel_details_list = [] 
        for i in range(num_records):
            details = {
            'VideoName': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['title']['runs'][0]['text'],
            'VideoLink': 'https://www.youtube.com' + yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url'],
            'VideoThumnail': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['thumbnail']['thumbnails'][3]['url'],
            'VideoTimeOfPost': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['publishedTimeText']['simpleText'],
            'VideoViews': yt_initial_data['contents']['twoColumnBrowseResultsRenderer']['tabs'][1]['tabRenderer']['content']['richGridRenderer']['contents'][i]['richItemRenderer']['content']['videoRenderer']['viewCountText']['simpleText']
            }
            channel_details_list.append(details)
        df = pd.DataFrame(channel_details_list)
    return df

# %%
df_yt =youtube_scrapping('https://www.youtube.com/@PW-Foundation/videos', 10)
df_yt
# Out:
#                                            VideoName  \
# 0  SCIENCE BOARD मैं कैसे आएँगे 100/100 🎯 | Impor...
# 1  FORCE AND LAWS OF MOTION in 1 Shot || FULL Cha...
# 2  LINEAR EQUATIONS IN TWO VARIABLES  in 1 Shot |...
# 3  POVERTY AS A CHALLENGE in 1 Shot || FULL Chapt...
# 4  COORDINATE GEOMETRY in 1 Shot || FULL Chapter ...
# 5  THE LOST CHILD + ADVENTURE OF TOTO in 1 Shot |...
# 6  SOCIALISM IN EUROPE & RUSSIAN REVOLUTION in 1 ...
# 7  THE FUNDAMENTAL UNIT OF LIFE in 1 Shot | FULL ...
# 8  TENSES + MODALS in 1 Shot | FULL Chapter Cover...
# 9  WHAT IS DEMOCRACY? WHY DEMOCRACY? in 1 Shot | ...
#
#                                      VideoLink  \
# 0  https://www.youtube.com/watch?v=J071v8HBuhw
# 1  https://www.youtube.com/watch?v=TovkhURONCA
# 2  https://www.youtube.com/watch?v=s6DFsuvWl-4
# 3  https://www.youtube.com/watch?v=SZb-hh03X8c
# 4  https://www.youtube.com/watch?v=CDJlqkp1hfI
# 5  https://www.youtube.com/watch?v=Hz9W7Jb_i1c
# 6  https://www.youtube.com/watch?v=tLpDFCbGLW4
# 7  https://www.youtube.com/watch?v=GGNN3cl57DQ
# 8  https://www.youtube.com/watch?v=YsyC6ZazIQA
# 9  https://www.youtube.com/watch?v=Z0Mo0JG-XdA
#
#                                        VideoThumnail VideoTimeOfPost  \
# 0  https://i.ytimg.com/vi/J071v8HBuhw/hqdefault.j...    17 hours ago
# 1  https://i.ytimg.com/vi/TovkhURONCA/hqdefault.j...       1 day ago
# 2  https://i.ytimg.com/vi/s6DFsuvWl-4/hqdefault.j...       1 day ago
# 3  https://i.ytimg.com/vi/SZb-hh03X8c/hqdefault.j...      2 days ago
# 4  https://i.ytimg.com/vi/CDJlqkp1hfI/hqdefault.j...      3 days ago
# 5  https://i.ytimg.com/vi/Hz9W7Jb_i1c/hqdefault.j...      3 days ago
# 6  https://i.ytimg.com/vi/tLpDFCbGLW4/hqdefault.j...      4 days ago
# 7  https://i.ytimg.com/vi/GGNN3cl57DQ/hqdefault.j...      5 days ago
# 8  https://i.ytimg.com/vi/YsyC6ZazIQA/hqdefault.j...      5 days ago
# 9  https://i.ytimg.com/vi/Z0Mo0JG-XdA/hqdefault.j...      6 days ago
#
#      VideoViews
# 0  96,163 views
# 1  10,116 views
# 2   7,524 views
# 3   7,373 views
# 4   8,775 views
# 5   5,658 views
# 6   7,777 views
# 7  33,659 views
# 8  11,030 views
# 9   8,711 views
